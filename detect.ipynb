# %%
from ultralytics import YOLO

# Load a pretrained YOLO11n model
model = YOLO("yolo11n.pt")

# Define remote image or video URL
source = "https://ultralytics.com/images/bus.jpg"

# Run inference on the source
results = model(source)  # list of Results objects
# Out:
# Found https://ultralytics.com/images/bus.jpg locally at bus.jpg
# image 1/1 C:\Users\goure\bus.jpg: 640x480 4 persons, 1 bus, 63.6ms
# Speed: 3.5ms preprocess, 63.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 480)

# %%
from PIL import Image

from ultralytics import YOLO

# Load a pretrained YOLO11n model
model = YOLO("yolo11n.pt")

# Run inference on 'bus.jpg'
results = model(["https://ultralytics.com/images/bus.jpg", "https://ultralytics.com/images/zidane.jpg"])  # results list

# Visualize the results
for i, r in enumerate(results):
    im_bgr = r.plot()                 # BGR numpy array
    im_rgb = Image.fromarray(im_bgr[..., ::-1])  # Convert to RGB PIL image
    
    display(im_rgb)                   # Show inside notebook
    
    r.save(filename=f"results{i}.jpg")
# Out:
# 0: 640x640 4 persons, 1 bus, 83.9ms
# 1: 640x640 2 persons, 1 tie, 83.9ms
# Speed: 4.4ms preprocess, 83.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# <PIL.Image.Image image mode=RGB size=810x1080>
# <PIL.Image.Image image mode=RGB size=1280x720>
